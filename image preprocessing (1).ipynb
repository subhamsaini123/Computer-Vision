# %%
import cv2

# %%
img1=cv2.imread("C:\\Users\\subha\\Downloads\\sherry-christian-8Myh76_3M2U-unsplash.jpg",1)
img1=cv2.resize(img1,(560,700))
print(img1)
cv2.imshow("original Image:",img1)


img2=cv2.imread("C:\\Users\\subha\\Downloads\\sherry-christian-8Myh76_3M2U-unsplash.jpg",0)
img2=cv2.resize(img2,(560,700))
print(img1)
cv2.imshow("Black Image:",img2)


img3=cv2.imread("C:\\Users\\subha\\Downloads\\sherry-christian-8Myh76_3M2U-unsplash.jpg",-1)
img3=cv2.resize(img3,(560,700))
print(img1)
cv2.imshow("Grey Image:",img3)


cv2.waitKey(10000)
cv2.destroyAllWindows()
# Out:
# [[[187 202 221]
#   [191 207 226]
#   [189 205 224]
#   ...
#   [ 54 119 138]
#   [ 47 111 130]
#   [ 55 116 136]]
#
#  [[181 196 215]
#   [182 197 216]
#   [184 199 218]
#   ...
#   [ 52 118 136]
#   [ 48 112 132]
#   [ 48 109 129]]
#
#  [[176 191 210]
#   [176 191 210]
#   [179 194 213]
#   ...
#   [ 57 123 142]
#   [ 60 124 144]
#   [ 58 119 139]]
#
#  ...
#
#  [[ 33  49  66]
#   [ 48  88 122]
#   [ 33  50  71]
#   ...
#   [142 106  76]
#   [143 107  77]
#   [147 111  81]]
#
#  [[ 18  38  55]
#   [ 64 102 133]
#   [ 48  61  79]
#   ...
#   [145 109  79]
#   [147 111  81]
#   [149 113  83]]
#
#  [[ 24  48  64]
#   [ 35  66  97]
#   [ 33  43  57]
#   ...
#   [146 110  80]
#   [147 111  81]
#   [150 114  84]]]
# [[[187 202 221]
#   [191 207 226]
#   [189 205 224]
#   ...
#   [ 54 119 138]
#   [ 47 111 130]
#   [ 55 116 136]]
#
#  [[181 196 215]
#   [182 197 216]
#   [184 199 218]
#   ...
#   [ 52 118 136]
#   [ 48 112 132]
#   [ 48 109 129]]
#
#  [[176 191 210]
#   [176 191 210]
# ...

# %%
path=input("Enter the path and name of an image:")
print("you enter this ==",path)

#now read image
img1=cv2.imread(path,0)
img1=cv2.resize(img1,(560,700))
#img1=cv2.flip(img1,1) #it accept 3 parameters 0,-1,1(rotate the image)
cv2.imshow("Converted Image:",img1)

cv2.waitKey(4000)
cv2.destroyAllWindows()
# Out:
# Enter the path and name of an image:C:\\Users\\subha\\Downloads\\sherry-christian-8Myh76_3M2U-unsplash.jpg
# you enter this == C:\\Users\\subha\\Downloads\\sherry-christian-8Myh76_3M2U-unsplash.jpg
